# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_ecommerce.csv")

# %%
print("Dataset shape:", df.shape)
print("\nColumn names:\n", df.columns.tolist())
# Out:
# Dataset shape: (1512, 23)
#
# Column names:
#  ['id', 'slug', 'title', 'imgs', 'brand', 'category', 'vendor', 'used', 'address', 'availability', 'currency', 'original_price', 'discounted_price', 'specifications', 'description', 'delivery_fee', 'warranty', 'warranty_type', 'average_rating', 'num_ratings', 'reviews', 'discount_pct', 'price_bucket']

# %%
sns.set(style="whitegrid", palette="muted")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
if 'product_id' in df.columns or 'Product_ID' in df.columns:
    prod_col = 'product_id' if 'product_id' in df.columns else 'Product_ID'
    top_products = df[prod_col].value_counts().head(10)

    sns.barplot(x=top_products.values, y=top_products.index, palette="viridis")
    plt.title("Top 10 Most Sold Products")
    plt.xlabel("Number of Sales")
    plt.ylabel("Product ID")
    plt.tight_layout()
    plt.show()

# %%
price_cols = [col for col in df.columns if 'price' in col.lower()]

if price_cols:
    sns.histplot(df[price_cols[0]], bins=30, kde=True, color='skyblue')
    plt.title("Price Distribution of Products")
    plt.xlabel("Price")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
rating_cols = [col for col in df.columns if 'rating' in col.lower()]

if price_cols and rating_cols:
    sns.scatterplot(x=df[price_cols[0]], y=df[rating_cols[0]], alpha=0.6, color='teal')
    plt.title("Relationship Between Price and Rating")
    plt.xlabel("Price")
    plt.ylabel("Rating")
    plt.tight_layout()
    plt.show()

# %%
cat_cols = [col for col in df.columns if 'category' in col.lower()]

if price_cols and cat_cols:
    sns.boxplot(x=df[cat_cols[0]], y=df[price_cols[0]], palette="coolwarm")
    plt.title("Price Distribution per Category")
    plt.xlabel("Category")
    plt.ylabel("Price")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\IC5\AppData\Local\Temp\ipykernel_9988\2702111992.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat_cols[0]], y=df[price_cols[0]], palette="coolwarm")

# %%
seg_cols = [
    col for col in df.columns
    if 'segment' in col.lower() or 'gender' in col.lower() or 'customer' in col.lower()
]

if seg_cols:
    sns.countplot(x=df[seg_cols[0]], palette="magma")
    plt.title(f"Distribution of {seg_cols[0].title()}")
    plt.xlabel(seg_cols[0].title())
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()
